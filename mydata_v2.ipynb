# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\SAmot\\OneDrive\\Desktop\\BBDS\\Data Science batch 15\\Group 15'

# %%
import pandas as pd
import numpy as np
mydata=pd.read_csv("colored_ad_click_table.csv")

# %%
#no of columns and rows
mydata.shape
# Out:
# (30, 41)

# %%
#loads the whole data
mydata
# Out:
#           Color  Click Count: Day 1  View Count: Day 1  Click Count: Day 2  \
# 0          Pink                  21                100                  20
# 1          Gray                  27                100                  27
# 2      Sapphire                  30                100                  32
# 3        Purple                  26                100                  21
# 4         Coral                  26                100                  24
# 5         Olive                  26                100                  19
# 6          Navy                  38                100                  29
# 7        Maroon                  21                100                  29
# 8          Teal                  25                100                  25
# 9          Cyan                  24                100                  22
# 10       Orange                  13                100                  28
# ...

# %%
#loads the first specified number of rows
mydata.head(10)
# Out:
#       Color  Click Count: Day 1  View Count: Day 1  Click Count: Day 2  \
# 0      Pink                  21                100                  20
# 1      Gray                  27                100                  27
# 2  Sapphire                  30                100                  32
# 3    Purple                  26                100                  21
# 4     Coral                  26                100                  24
# 5     Olive                  26                100                  19
# 6      Navy                  38                100                  29
# 7    Maroon                  21                100                  29
# 8      Teal                  25                100                  25
# 9      Cyan                  24                100                  22
#
#    View Count: Day 2  Click Count: Day 3  View Count: Day 3  \
# 0                100                  14                100
# 1                100                  26                100
# ...

# %%
##loads the last specified number of rows
mydata.tail(10)
# Out:
#           Color  Click Count: Day 1  View Count: Day 1  Click Count: Day 2  \
# 20  Ultramarine                  49                100                  41
# 21       Yellow                  14                100                  24
# 22      Virdian                  27                100                  23
# 23       Violet                  15                100                  22
# 24        Green                  14                100                  25
# 25   Aquamarine                  24                100                  28
# 26      Magenta                  18                100                  21
# 27       Silver                  26                100                  24
# 28       Bronze                  19                100                  19
# 29         Lime                  20                100                  19
#
#     View Count: Day 2  Click Count: Day 3  View Count: Day 3  \
# 20                100                  24                100
# ...

# %%
#statistically describes the data
mydata.describe()
# Out:
#        Click Count: Day 1  View Count: Day 1  Click Count: Day 2  \
# count           30.000000               30.0           30.000000
# mean            23.533333              100.0           24.433333
# std              7.454382                0.0            5.864465
# min             12.000000              100.0           15.000000
# 25%             19.250000              100.0           21.000000
# 50%             24.000000              100.0           24.000000
# 75%             26.750000              100.0           28.000000
# max             49.000000              100.0           41.000000
#
#        View Count: Day 2  Click Count: Day 3  View Count: Day 3  \
# count               30.0           30.000000               30.0
# mean               100.0           24.066667              100.0
# std                  0.0            5.381535                0.0
# min                100.0           14.000000              100.0
# ...

# %%
mydata.describe().transpose()
# Out:
#                      count        mean       std    min     25%    50%  \
# Click Count: Day 1    30.0   23.533333  7.454382   12.0   19.25   24.0
# View Count: Day 1     30.0  100.000000  0.000000  100.0  100.00  100.0
# Click Count: Day 2    30.0   24.433333  5.864465   15.0   21.00   24.0
# View Count: Day 2     30.0  100.000000  0.000000  100.0  100.00  100.0
# Click Count: Day 3    30.0   24.066667  5.381535   14.0   20.50   24.0
# View Count: Day 3     30.0  100.000000  0.000000  100.0  100.00  100.0
# Click Count: Day 4    30.0   24.366667  5.738457   16.0   20.00   23.0
# View Count: Day 4     30.0  100.000000  0.000000  100.0  100.00  100.0
# Click Count: Day 5    30.0   25.466667  6.516469   12.0   21.25   25.0
# View Count: Day 5     30.0  100.000000  0.000000  100.0  100.00  100.0
# Click Count: Day 6    30.0   23.533333  5.986959   11.0   22.00   23.0
# View Count: Day 6     30.0  100.000000  0.000000  100.0  100.00  100.0
# ...

# %%
#gives type of object in each colmn and count
#also tells you if there are any empty/missing values
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 41 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Color                30 non-null     object
#  1   Click Count: Day 1   30 non-null     int64
#  2   View Count: Day 1    30 non-null     int64
#  3   Click Count: Day 2   30 non-null     int64
#  4   View Count: Day 2    30 non-null     int64
#  5   Click Count: Day 3   30 non-null     int64
#  6   View Count: Day 3    30 non-null     int64
#  7   Click Count: Day 4   30 non-null     int64
#  8   View Count: Day 4    30 non-null     int64
#  9   Click Count: Day 5   30 non-null     int64
#  10  View Count: Day 5    30 non-null     int64
#  11  Click Count: Day 6   30 non-null     int64
#  12  View Count: Day 6    30 non-null     int64
#  13  Click Count: Day 7   30 non-null     int64
#  14  View Count: Day 7    30 non-null     int64
# ...

# %%
#gives you all the column names
mydata.columns
# Out:
# Index(['Color', 'Click Count: Day 1', 'View Count: Day 1',
#        'Click Count: Day 2', 'View Count: Day 2', 'Click Count: Day 3',
#        'View Count: Day 3', 'Click Count: Day 4', 'View Count: Day 4',
#        'Click Count: Day 5', 'View Count: Day 5', 'Click Count: Day 6',
#        'View Count: Day 6', 'Click Count: Day 7', 'View Count: Day 7',
#        'Click Count: Day 8', 'View Count: Day 8', 'Click Count: Day 9',
#        'View Count: Day 9', 'Click Count: Day 10', 'View Count: Day 10',
#        'Click Count: Day 11', 'View Count: Day 11', 'Click Count: Day 12',
#        'View Count: Day 12', 'Click Count: Day 13', 'View Count: Day 13',
#        'Click Count: Day 14', 'View Count: Day 14', 'Click Count: Day 15',
#        'View Count: Day 15', 'Click Count: Day 16', 'View Count: Day 16',
#        'Click Count: Day 17', 'View Count: Day 17', 'Click Count: Day 18',
#        'View Count: Day 18', 'Click Count: Day 19', 'View Count: Day 19',
# ...

# %%
to_delete = []
for i in mydata.columns:
    if "View" in i:
        to_delete.append(i)
to_delete
# Out:
# ['View Count: Day 1',
#  'View Count: Day 2',
#  'View Count: Day 3',
#  'View Count: Day 4',
#  'View Count: Day 5',
#  'View Count: Day 6',
#  'View Count: Day 7',
#  'View Count: Day 8',
#  'View Count: Day 9',
#  'View Count: Day 10',
#  'View Count: Day 11',
#  'View Count: Day 12',
#  'View Count: Day 13',
#  'View Count: Day 14',
#  'View Count: Day 15',
#  'View Count: Day 16',
#  'View Count: Day 17',
#  'View Count: Day 18',
#  'View Count: Day 19',
#  'View Count: Day 20']

# %%
mydataV2 = mydata.drop(to_delete, axis=1)

# %%
mydataV2
# Out:
#           Color  Click Count: Day 1  Click Count: Day 2  Click Count: Day 3  \
# 0          Pink                  21                  20                  14
# 1          Gray                  27                  27                  26
# 2      Sapphire                  30                  32                  30
# 3        Purple                  26                  21                  16
# 4         Coral                  26                  24                  25
# 5         Olive                  26                  19                  20
# 6          Navy                  38                  29                  30
# 7        Maroon                  21                  29                  24
# 8          Teal                  25                  25                  32
# 9          Cyan                  24                  22                  34
# 10       Orange                  13                  28                  24
# ...

# %%
#! pip install pyjanitor==0.21.2

import janitor

mydata_v2=pd.DataFrame(mydataV2)
mydata_v2["Total_clicks"] = mydataV2.sum(axis=1)
mydata_v2= mydata_v2.clean_names()
# Out:
# C:\Users\SAmot\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %%
mydata_v2
#mydata_v2.shape
# Out:
#           color  click_count_day_1  click_count_day_2  click_count_day_3  \
# 0          Pink                 21                 20                 14
# 1          Gray                 27                 27                 26
# 2      Sapphire                 30                 32                 30
# 3        Purple                 26                 21                 16
# 4         Coral                 26                 24                 25
# 5         Olive                 26                 19                 20
# 6          Navy                 38                 29                 30
# 7        Maroon                 21                 29                 24
# 8          Teal                 25                 25                 32
# 9          Cyan                 24                 22                 34
# 10       Orange                 13                 28                 24
# 11        Black                 27                 25                 28
# ...

# %%
features = ['color', 'total_clicks']

mydata_v2[features].hist(figsize=(30, 10));

# %%
mydata_v2[features].plot(kind='density', subplots=True, layout=(2, 2), 
                  sharex=False, figsize=(10, 10));

# %%
#! pip install seaborn
import seaborn as sns
import matplotlib.pyplot as plt
#mydata_v2= sns.load_dataset("mydata_v2")
#_, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 7))
#plt.figure(figsize=(100,30))
sns.set(rc={'figure.figsize':(40,50)})

sns.relplot(x='color', y='total_clicks',kind = 'line',data=mydata_v2);
#sns.countplot(x='incident_state', data=autinsurance, ax=axes[1]);

# %%
#import pandas_profiling

#mydata_v2.profile_report()

# %%
display(mydata_v2.iloc[1][0])
print(mydata_v2.iloc[0][0])
# Out:
# 'Gray'
# Pink

# %%
colors = []
mydata_v2.Color
colors.append(mydata_v2.Color)
colors
# Out:
# [0            Pink
#  1            Gray
#  2        Sapphire
#  3          Purple
#  4           Coral
#  5           Olive
#  6            Navy
#  7          Maroon
#  8            Teal
#  9            Cyan
#  10         Orange
#  11          Black
#  12            Tan
#  13            Red
#  14           Blue
#  15          Brown
#  16      Turquoise
#  17         Indigo
#  18           Gold
#  19           Jade
#  20    Ultramarine
#  21         Yellow
#  22        Virdian
#  23         Violet
#  24          Green
#  25     Aquamarine
#  26        Magenta
#  27         Silver
#  28         Bronze
#  29           Lime
#  Name: Color, dtype: object]
